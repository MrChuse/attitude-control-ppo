# %% [markdown]
# # Proximal Policy Optimization
#
# **Author:** [Ilias Chrysovergis](https://twitter.com/iliachry)<br>
# **Date created:** 2021/06/24<br>
# **Last modified:** 2021/06/24<br>
# **Description:** Implementation of a Proximal Policy Optimization agent for the CartPole-v0 environment.

# %% [markdown]
# ## Introduction
#
# This code example solves the CartPole-v0 environment using a Proximal Policy Optimization (PPO) agent.
#
# ### CartPole-v0
#
# A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track.
# The system is controlled by applying a force of +1 or -1 to the cart.
# The pendulum starts upright, and the goal is to prevent it from falling over.
# A reward of +1 is provided for every timestep that the pole remains upright.
# The episode ends when the pole is more than 15 degrees from vertical, or the cart moves more than 2.4 units from the center.
# After 200 steps the episode ends. Thus, the highest return we can get is equal to 200.
#
# [CartPole-v0](https://gym.openai.com/envs/CartPole-v0/)
#
# ### Proximal Policy Optimization
#
# PPO is a policy gradient method and can be used for environments with either discrete or continuous action spaces.
# It trains a stochastic policy in an on-policy way. Also, it utilizes the actor critic method. The actor maps the
# observation to an action and the critic gives an expectation of the rewards of the agent for the observation given.
# Firstly, it collects a set of trajectories for each epoch by sampling from the latest version of the stochastic policy.
# Then, the rewards-to-go and the advantage estimates are computed in order to update the policy and fit the value function.
# The policy is updated via a stochastic gradient ascent optimizer, while the value function is fitted via some gradient descent algorithm.
# This procedure is applied for many epochs until the environment is solved.
#
# ![Algorithm](https://i.imgur.com/rd5tda1.png)
#
# - [PPO Original Paper](https://arxiv.org/pdf/1707.06347.pdf)
# - [OpenAI Spinning Up docs - PPO](https://spinningup.openai.com/en/latest/algorithms/ppo.html)
#
# ### Note
#
# This code example uses Keras and Tensorflow v2. It is based on the PPO Original Paper,
# the OpenAI's Spinning Up docs for PPO, and the OpenAI's Spinning Up implementation of PPO using Tensorflow v1.
#
# [OpenAI Spinning Up Github - PPO](https://github.com/openai/spinningup/blob/master/spinup/algos/tf1/ppo/ppo.py)

# %% [markdown]
# ## Libraries
#
# For this example the following libraries are used:
#
# 1. `numpy` for n-dimensional arrays
# 2. `tensorflow` and `keras` for building the deep RL PPO agent
# 3. `gym` for getting everything we need about the environment
# 4. `scipy.signal` for calculating the discounted cumulative sums of vectors

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import gym
import scipy.signal
import time
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# %% [markdown]
# ## Functions and class

# %%
def discounted_cumulative_sums(x, discount):
    # Discounted cumulative sums of vectors for computing rewards-to-go and advantage estimates
    return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]


class Buffer:
    # Buffer for storing trajectories
    def __init__(self, observation_dimensions, size, gamma=0.99, lam=0.95):
        # Buffer initialization
        self.observation_buffer = np.zeros(
            (size, observation_dimensions), dtype=np.float32
        )
        self.action_buffer = np.zeros(size, dtype=np.int32)
        self.advantage_buffer = np.zeros(size, dtype=np.float32)
        self.reward_buffer = np.zeros(size, dtype=np.float32)
        self.return_buffer = np.zeros(size, dtype=np.float32)
        self.value_buffer = np.zeros(size, dtype=np.float32)
        self.logprobability_buffer = np.zeros(size, dtype=np.float32)
        self.gamma, self.lam = gamma, lam
        self.pointer, self.trajectory_start_index = 0, 0

    def store(self, observation, action, reward, value, logprobability):
        # Append one step of agent-environment interaction
        self.observation_buffer[self.pointer] = observation
        self.action_buffer[self.pointer] = action
        self.reward_buffer[self.pointer] = reward
        self.value_buffer[self.pointer] = value
        self.logprobability_buffer[self.pointer] = logprobability
        self.pointer += 1

    def finish_trajectory(self, last_value=0):
        # Finish the trajectory by computing advantage estimates and rewards-to-go
        path_slice = slice(self.trajectory_start_index, self.pointer)
        rewards = np.append(self.reward_buffer[path_slice], last_value)
        values = np.append(self.value_buffer[path_slice], last_value)

        deltas = rewards[:-1] + self.gamma * values[1:] - values[:-1]

        self.advantage_buffer[path_slice] = discounted_cumulative_sums(
            deltas, self.gamma * self.lam
        )
        self.return_buffer[path_slice] = discounted_cumulative_sums(
            rewards, self.gamma
        )[:-1]

        self.trajectory_start_index = self.pointer

    def get(self):
        # Get all data of the buffer and normalize the advantages
        self.pointer, self.trajectory_start_index = 0, 0
        advantage_mean, advantage_std = (
            np.mean(self.advantage_buffer),
            np.std(self.advantage_buffer),
        )
        self.advantage_buffer = (self.advantage_buffer - advantage_mean) / advantage_std
        return (
            self.observation_buffer,
            self.action_buffer,
            self.advantage_buffer,
            self.return_buffer,
            self.logprobability_buffer,
        )


def mlp(x, sizes, activation=tf.nn.relu, output_activation=None):
    # Build a feedforward neural network
    for size in sizes[:-1]:
        x = layers.Dense(units=size, activation=activation)(x)
    return layers.Dense(units=sizes[-1], activation=output_activation)(x)


def logprobabilities(logits, a):
    # Compute the log-probabilities of taking actions a by using the logits (i.e. the output of the actor)
    logprobabilities_all = tf.nn.log_softmax(logits)
    logprobability = tf.reduce_sum(
        tf.one_hot(a, num_actions) * logprobabilities_all, axis=1
    )
    return logprobability


# Sample action from actor
@tf.function
def sample_action(observation):
    logits = actor(observation)
    action = tf.squeeze(tf.random.categorical(logits, 1), axis=1)
    return logits, action


# Train the policy by maxizing the PPO-Clip objective
@tf.function
def train_policy(
    observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
):

    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        ratio = tf.exp(
            logprobabilities(actor(observation_buffer), action_buffer)
            - logprobability_buffer
        )
        min_advantage = tf.where(
            advantage_buffer > 0,
            (1 + clip_ratio) * advantage_buffer,
            (1 - clip_ratio) * advantage_buffer,
        )

        policy_loss = -tf.reduce_mean(
            tf.minimum(ratio * advantage_buffer, min_advantage)
        )
    policy_grads = tape.gradient(policy_loss, actor.trainable_variables)
    policy_optimizer.apply_gradients(zip(policy_grads, actor.trainable_variables))

    kl = tf.reduce_mean(
        logprobability_buffer
        - logprobabilities(actor(observation_buffer), action_buffer)
    )
    kl = tf.reduce_sum(kl)
    return kl


# Train the value function by regression on mean-squared error
@tf.function
def train_value_function(observation_buffer, return_buffer):
    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        value_loss = tf.reduce_mean((return_buffer - critic(observation_buffer)) ** 2)
    value_grads = tape.gradient(value_loss, critic.trainable_variables)
    value_optimizer.apply_gradients(zip(value_grads, critic.trainable_variables))

# %% [markdown]
# ## Hyperparameters

# %%
# Hyperparameters of the PPO algorithm
steps_per_epoch = 500
epochs = 1000
gamma = 0.99
clip_ratio = 0.2
policy_learning_rate = 3e-4
value_function_learning_rate = 1e-3
train_policy_iterations = 80
train_value_iterations = 80
lam = 0.95
target_kl = 0.01
hidden_sizes = (400, 300)

# True if you want to render the environment
render = False

# %%
def plot_euler_angles(t, roll, pitch, yaw, filename=None):
  fig1 = plt.figure(figsize=(8,8))
  ax1 = fig1.add_subplot(1,1,1)
  ax1.set_title("Euler Angles")
  ax1.plot(t, roll, label = 'roll', color = 'red')
  ax1.plot(t, pitch, label = 'pitch', color = 'green')
  ax1.plot(t, yaw, label = 'yaw', color = 'blue')
  #ax1.set_ybound(-10, 10)
  ax1.set_ylabel(r'angles, [deg]')
  ax1.set_xlabel(r't, [s]')
  ax1.grid(True)
  ax1.legend()
  fig1.show()
  if filename is not None:
    fig1.savefig(f'{filename}')

def plot_euler_angles_radial(t, roll, pitch, yaw, filename=None):
  fig1 = plt.figure(figsize=(8,8))
  ax1 = fig1.add_subplot(1,1,1, polar=True)
  ax1.set_title("Euler Angles")
  ax1.plot(roll, t, label = 'roll', color = 'red')
  ax1.plot(pitch, t, label = 'pitch', color = 'green')
  ax1.plot(yaw, t, label = 'yaw', color = 'blue')
  #ax1.set_ylabel(r'angles, [deg]')
  #ax1.set_xlabel(r't, [s]')
  ax1.grid(True)
  ax1.legend()
  fig1.show()
  if filename is not None:
    fig1.savefig(f'{filename}')

def plot_phase_diagram(roll, pitch, yaw, omega_, filename=None):
  fig2 = plt.figure(figsize=(8,8))
  ax2 = fig2.add_subplot(1,1,1)
  ax2.set_title("Phase diagram")
  ax2.plot(roll, omega_[0], label = 'roll', color = 'red')
  ax2.plot(pitch, omega_[1], label = 'pitch', color = 'green')
  ax2.plot(yaw, omega_[2], label = 'yaw', color = 'blue')
  ax2.plot([0],[0], 'o', markersize=8 , label='Destination', color = 'magenta')
  ax2.set_xlabel(r'$\alpha$')
  ax2.set_ylabel(r'$\omega$')
  ax2.legend()
  ax2.grid()
  fig2.show()
  if filename is not None:
    fig2.savefig(f'{filename}')

# %%
# Вспомогательные функции

def normalize(obj):

    return obj / np.linalg.norm(obj)


def cross_product(a, b):

    def check_dimensions(vec, string):

        if vec.ndim != 1:
            raise Exception("The {} input is not a vector".format(string))
        if len(vec) != 3:
            raise Exception("Wrong number of coordinates in the {0} vector: {1}, should be 3".format(string, len(vec)))

    check_dimensions(a, 'first')
    check_dimensions(b, 'second')

    return np.array([a[1]*b[2]-a[2]*b[1], a[2]*b[0]-a[0]*b[2], a[0]*b[1] - a[1]*b[0]])

def quat_product(q1, q2):

    def check_dimensions(q, string):

        if q.ndim != 1:
            raise Exception("The {} input is not a quaternion".format(string))
        if len(q) != 4:
            raise Exception("Wrong number of coordinates in the {0} quaternion: {1}, should be 4".format(string, len(q)))

    check_dimensions(q1, 'first')
    check_dimensions(q2, 'second')

    q = np.zeros(4)
    q[0] = q1[0] * q2[0] - q1[1:].dot(q2[1:])
    q[1:] = q1[0] * q2[1:] + q2[0] * q1[1:] + cross_product(q1[1:], q2[1:])

    return q

def rotate_vec_with_quat(q, vec):

    def check_dimensions(obj, is_quat):

        if obj.ndim != 1:
            raise Exception("Not a {}".format('quaternion' * is_quat + 'vector' * (1 - is_quat)))
        if len(obj) != (3 + 1 * is_quat):
            raise Exception("Wrong number of coordinates in the {0}: {1}, should be {2}"
                            .format('quaternion' * is_quat + 'vector' * (1 - is_quat), len(obj), 3 + 1 * is_quat))

    check_dimensions(q, True)
    check_dimensions(vec, False)

    q = quat_conjugate(q)

    qxvec = cross_product(q[1:], vec)

    return q[1:].dot(vec) * q[1:] + q[0]**2. * vec + 2. * q[0] * qxvec + cross_product(q[1:], qxvec)

def quat2rpy(q0, q1, q2, q3):

    roll = np.arctan2(2. * (q0 * q1 + q2 * q3), 1. - 2. * (q1**2 + q2**2))
    pitch = np.arcsin(2. * (q0 * q2 - q1 * q3))
    yaw = np.arctan2(2. * (q0 * q3 + q1 * q2), 1. - 2. * (q2**2 + q3**2))

    return [roll, pitch, yaw]

def quat2rpy_deg(q0, q1, q2, q3):

    roll = np.arctan2(2. * (q0 * q1 + q2 * q3), 1. - 2. * (q1**2 + q2**2))*180/np.pi
    pitch = np.arcsin(2. * (q0 * q2 - q1 * q3))*180/np.pi
    yaw = np.arctan2(2. * (q0 * q3 + q1 * q2), 1. - 2. * (q2**2 + q3**2))*180/np.pi

    return [roll, pitch, yaw]

def quat_conjugate(q):

    q_new = np.copy(q)
    q_new[1:] = q_new[1:] * -1.

    return q_new

def gravity_gradient_torque(quat, inertia_tensor, mean_motion):
    Ae3 = rotate_vec_with_quat(quat, np.array([0., 0., 1.]))

    return 3. * mean_motion ** 2. * cross_product(Ae3, inertia_tensor.dot(Ae3))    


def rhs(t, x, sat, action):

    quat = x[:4] / np.linalg.norm(x[:4])
    omega = x[4:7]
    h = x[7:10]
     
    omega_rel = omega - rotate_vec_with_quat(quat, np.array([0., sat.mean_motion, 0.]))    
        
    trq_gg = gravity_gradient_torque(quat, sat.J, sat.mean_motion)       

    x_dot = np.zeros(10)
    action = action.reshape(3,)
    x_dot[0] = -0.5 * quat[1:].dot(omega_rel)
    x_dot[1:4] = 0.5 * (quat[0] * omega + cross_product(quat[1:], omega_rel))
    tmp3 = (trq_gg + action - cross_product(omega, sat.J.dot(omega)))
    x_dot[4:7] = sat.J_inv.dot(tmp3)
    x_dot[7:10] = - action
    
    return x_dot

# %%
from types import SimpleNamespace
const = SimpleNamespace()
const.mu = 3.986e14
const.Re = 6037.1e3
sat = SimpleNamespace()
sat.J = np.diag(np.array([4, 5, 3]))
sat.J_inv = np.linalg.inv(sat.J)
sat.altitude = 600e3
sat.mean_motion = np.sqrt(const.mu / (const.Re + sat.altitude)**3.)


class TorqueDynamics(gym.Env):
  observation_space = gym.spaces.Box(-1, 1, shape=(10,))

  
  def __init__(self, dt, q_req, add_9=0.25):
    self.state = None
    self.dt = dt
    self.q_req = q_req
    self.q_req_conj = quat_conjugate(self.q_req)
    self.w_req = np.zeros(3)
    self.history = []
    self.t = []
    self.action_space = self.init_actions()
    self.q_prev = None
    self.add_9 = add_9

  @staticmethod
  def init_actions():
    a = np.linspace(-1, 1, 21)
    a1 = a/10
    a2 = a/100
    a = np.concatenate((a, a1, a2))
    a = np.unique(a.round(10))
    a = a[a>=-0.5]
    a = a[a<=0.5]

    s = a.shape
    a = np.vstack((a, np.zeros(s)))
    a = np.vstack((a, np.zeros(s)))
    a = a.T
    aroll1 = np.roll(a, 1)
    aroll2 = np.roll(a, 2)
    a = np.concatenate((a, aroll1))
    a = np.concatenate((a, aroll2))
    a = np.unique(a, axis=0)
    return a

  def reset(self, state=None):
    if state is not None:
      self.state = state
    else:
      self.state = self.observation_space.sample()
      phi = self.state[0] * np.pi 
      self.state[0] = np.cos(phi / 2)
      self.state[1:4] = normalize(self.state[1:4]) * np.sin(phi / 2)
      self.state[4:] = 0
    self.history = [self.state]
    self.t = [0]
    self.q_prev = self.state[:4]
    return self.state

  @staticmethod
  def r_a(phi, q_current, q_prev):
    return np.exp(-phi/(0.14*2*np.pi)) if q_current > q_prev else np.exp(-phi/(0.14*2*np.pi)) - 1


  def r_t(self, reward, phi):
    return reward + 9 if phi <= self.add_9 else reward

  def step(self, action):
    t0 = 0
    tf = self.dt
    x_0 = self.state
    if isinstance(action, int) or isinstance(action, np.int64):
      action = self.action_space[action].reshape(3,1)
    
    sol = solve_ivp(lambda t, x: rhs(t, x, sat, action), (t0,tf), x_0)#, t_eval=t_eval)
    x = sol.y.T
    t = sol.t[1:]
    observation = x[-1]
    observations = normalize(observation)
    time_ = self.t[-1] + self.dt
    self.state = observation
    self.history.append(observation)
    self.t.append(time_)

    # calculating rewards:
    q_current = observation[:4]
    q_error = quat_product(self.q_req_conj, q_current)
    q_error = np.clip(q_error, -1, 1)
    w_current = observation[4:7]
    #print('q_error', q_error)
    phi = 2*np.arccos(q_error[0])
    r_inter = self.r_a(phi, q_current[0], self.q_prev[0])
    r1 = self.r_t(r_inter, phi)
    # r2 = -np.sum(np.abs(observation[4:7]))
    # Qreward = np.exp(-0.1 * np.linalg.norm(q_current - self.q_req))
    # Wreward = np.exp(-0.1 * np.linalg.norm(w_current - self.w_req))
    # reward = Qreward * Wreward
    # reward = self.r_t(reward, phi)
    reward = r1 # + 10 * r2
    #print('rewards', r1, r2)
    self.q_prev = q_current

    q_req_ext = np.concatenate([self.q_req, self.w_req])
    done = np.linalg.norm(observation[:7] - q_req_ext) < 1e-4
    
    info = dict()
    info['x'] = self.history
    info['t'] = self.t
    return observation, reward, done, info
  
  def render(self):
    pass

# %% [markdown]
# ## Initializations

# %%
# Initialize the environment and get the dimensionality of the
# observation space and the number of possible actions
env = TorqueDynamics(0.1, np.array([1, 0, 0, 0]), 0.05)
observation_dimensions = env.observation_space.shape[0]
num_actions = env.action_space.shape[0]

# Initialize the buffer
buffer = Buffer(observation_dimensions, steps_per_epoch)

# Initialize the actor and the critic as keras models
observation_input = keras.Input(shape=(observation_dimensions,), dtype=tf.float32)
logits = mlp(observation_input, list(hidden_sizes) + [num_actions], tf.nn.relu, None)
actor = keras.Model(inputs=observation_input, outputs=logits)
value = tf.squeeze(
    mlp(observation_input, list(hidden_sizes) + [1], tf.nn.relu, None), axis=1
)
critic = keras.Model(inputs=observation_input, outputs=value)

# Initialize the policy and the value function optimizers
policy_optimizer = keras.optimizers.Adam(learning_rate=policy_learning_rate)
value_optimizer = keras.optimizers.Adam(learning_rate=value_function_learning_rate)

# %% [markdown]
# ## Train

# %%
def train(epochs, add_9, start=None):
# Iterate over the number of epochs
  print('starting training with', epochs, 'epochs')
  buffer = Buffer(observation_dimensions, steps_per_epoch)
  env = TorqueDynamics(0.1, np.array([1, 0, 0, 0]), add_9)
  # Initialize the observation, episode return and episode length
  observation, episode_return, episode_length = env.reset(start), 0, 0

  returns = []

  for epoch in range(epochs):
      # Initialize the sum of the returns, lengths and number of episodes for each epoch
      sum_return = 0
      sum_length = 0
      num_episodes = 0

      # Iterate over the steps of each epoch
      for t in range(steps_per_epoch):
          if render:
              env.render()

          # Get the logits, action, and take one step in the environment
          observation = observation.reshape(1, -1)
          logits, action = sample_action(observation)
          #print(type(action[0].numpy()))
          observation_new, reward, done, info = env.step(action[0].numpy())
          episode_return += reward
          episode_length += 1

          # Get the value and log-probability of the action
          value_t = critic(observation)
          logprobability_t = logprobabilities(logits, action)

          # Store obs, act, rew, v_t, logp_pi_t
          buffer.store(observation, action, reward, value_t, logprobability_t)

          # Update the observation
          observation = observation_new

          # Finish trajectory if reached to a terminal state
          terminal = done
          if terminal or (t == steps_per_epoch - 1):
              last_value = 0 if done else critic(observation.reshape(1, -1))
              buffer.finish_trajectory(last_value)
              sum_return += episode_return
              sum_length += episode_length
              num_episodes += 1
              observation, episode_return, episode_length = env.reset(start), 0, 0

      # Get values from the buffer
      (
          observation_buffer,
          action_buffer,
          advantage_buffer,
          return_buffer,
          logprobability_buffer,
      ) = buffer.get()

      # Update the policy and implement early stopping using KL divergence
      for _ in range(train_policy_iterations):
          kl = train_policy(
              observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
          )
          if kl > 1.5 * target_kl:
              # Early Stopping
              break

      # Update the value function
      for _ in range(train_value_iterations):
          train_value_function(observation_buffer, return_buffer)

      # Print mean return and length for each epoch
      print(
          f" Epoch: {epoch + 1}. Mean Return: {sum_return / num_episodes}. Mean Length: {sum_length / num_episodes}"
      )
      returns.append(sum_return / num_episodes)
  return returns

# %%
print('Accounting for the gravity')
iterations = 20
reward_thresh = 0.1
tries = 100

for i in range(tries):
  print(f'Run #{i}. The "+9" threshold is {reward_thresh}')
  mean_ret = train(iterations, reward_thresh)
  mean_ret = np.min(mean_ret)
  print(f'Current batch mean is {mean_ret}')
  print('-'*10)
  if mean_ret > 300 and reward_thresh > 0.004:
    reward_thresh *= 0.5# - 3*(mean_ret - 1000)/40000 # linear from (1000, 0.8) to (5000, 0.5)
# Out:
# Accounting for the gravity
# Run #0. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 146.11253211442892. Mean Length: 500.0
#  Epoch: 2. Mean Return: 3433.119717649989. Mean Length: 500.0
#  Epoch: 3. Mean Return: 1782.7904778076538. Mean Length: 500.0
#  Epoch: 4. Mean Return: 3574.2361205030033. Mean Length: 500.0
#  Epoch: 5. Mean Return: 2385.107074243258. Mean Length: 500.0
#  Epoch: 6. Mean Return: 197.7506500018071. Mean Length: 500.0
#  Epoch: 7. Mean Return: 136.04839671419674. Mean Length: 500.0
#  Epoch: 8. Mean Return: 147.8753880940329. Mean Length: 500.0
#  Epoch: 9. Mean Return: 2939.422868617589. Mean Length: 500.0
#  Epoch: 10. Mean Return: 3854.484091796802. Mean Length: 500.0
#  Epoch: 11. Mean Return: 3817.1926167595852. Mean Length: 500.0
#  Epoch: 12. Mean Return: 183.42459705400512. Mean Length: 500.0
#  Epoch: 13. Mean Return: 2742.431764373067. Mean Length: 500.0
#  Epoch: 14. Mean Return: 4110.840587682069. Mean Length: 500.0
#  Epoch: 15. Mean Return: 3403.328568670828. Mean Length: 500.0
#  Epoch: 16. Mean Return: 158.94850907894897. Mean Length: 500.0
#  Epoch: 17. Mean Return: 3992.1449339211385. Mean Length: 500.0
#  Epoch: 18. Mean Return: 34.65332783733694. Mean Length: 500.0
#  Epoch: 19. Mean Return: 3002.2134733147795. Mean Length: 500.0
#  Epoch: 20. Mean Return: 133.73100610910248. Mean Length: 500.0
# Current batch mean is 34.65332783733694
# ----------
# Run #1. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 141.44962355463755. Mean Length: 500.0
#  Epoch: 2. Mean Return: 151.0235164496816. Mean Length: 500.0
#  Epoch: 3. Mean Return: 176.6660986042325. Mean Length: 500.0
#  Epoch: 4. Mean Return: 134.07426310921133. Mean Length: 500.0
#  Epoch: 5. Mean Return: 2894.2808709498904. Mean Length: 500.0
#  Epoch: 6. Mean Return: 2787.3391421650076. Mean Length: 500.0
#  Epoch: 7. Mean Return: 2989.1520138219203. Mean Length: 500.0
#  Epoch: 8. Mean Return: 3754.264805874678. Mean Length: 500.0
#  Epoch: 9. Mean Return: 1996.5596181956716. Mean Length: 500.0
#  Epoch: 10. Mean Return: 601.9009717961472. Mean Length: 500.0
#  Epoch: 11. Mean Return: 4002.1149288153406. Mean Length: 500.0
#  Epoch: 12. Mean Return: 4336.521080018637. Mean Length: 500.0
#  Epoch: 13. Mean Return: 3389.8603070654935. Mean Length: 500.0
#  Epoch: 14. Mean Return: 3983.729358445851. Mean Length: 500.0
#  Epoch: 15. Mean Return: 4740.669384076587. Mean Length: 500.0
#  Epoch: 16. Mean Return: 210.70249161076018. Mean Length: 500.0
#  Epoch: 17. Mean Return: 48.119709308534446. Mean Length: 500.0
#  Epoch: 18. Mean Return: 273.3365610015503. Mean Length: 500.0
#  Epoch: 19. Mean Return: 3394.77528365272. Mean Length: 500.0
#  Epoch: 20. Mean Return: 311.95350835249786. Mean Length: 500.0
# Current batch mean is 48.119709308534446
# ----------
# Run #2. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 3844.0227488529345. Mean Length: 500.0
#  Epoch: 2. Mean Return: 172.11242141724134. Mean Length: 500.0
#  Epoch: 3. Mean Return: 209.96461021161545. Mean Length: 500.0
#  Epoch: 4. Mean Return: 194.66570051684766. Mean Length: 500.0
#  Epoch: 5. Mean Return: 3739.5571518615084. Mean Length: 500.0
#  Epoch: 6. Mean Return: 245.59333250543162. Mean Length: 500.0
#  Epoch: 7. Mean Return: 211.90487252647512. Mean Length: 500.0
#  Epoch: 8. Mean Return: 3951.110560303049. Mean Length: 500.0
#  Epoch: 9. Mean Return: 195.79293004640468. Mean Length: 500.0
#  Epoch: 10. Mean Return: 56.20136679763258. Mean Length: 500.0
#  Epoch: 11. Mean Return: 2798.597962877243. Mean Length: 500.0
#  Epoch: 12. Mean Return: 4028.3454701324954. Mean Length: 500.0
#  Epoch: 13. Mean Return: 201.06679915122444. Mean Length: 500.0
#  Epoch: 14. Mean Return: 92.052292309987. Mean Length: 500.0
#  Epoch: 15. Mean Return: 1242.3886272931197. Mean Length: 500.0
#  Epoch: 16. Mean Return: 4025.1470664150324. Mean Length: 500.0
#  Epoch: 17. Mean Return: 944.5608043961196. Mean Length: 500.0
#  Epoch: 18. Mean Return: 1108.164214167636. Mean Length: 500.0
#  Epoch: 19. Mean Return: 3634.091972306701. Mean Length: 500.0
#  Epoch: 20. Mean Return: 3050.8048519967365. Mean Length: 500.0
# Current batch mean is 56.20136679763258
# ----------
# Run #3. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 4124.401136784318. Mean Length: 500.0
#  Epoch: 2. Mean Return: 226.57803372891118. Mean Length: 500.0
#  Epoch: 3. Mean Return: 308.28047978592986. Mean Length: 500.0
#  Epoch: 4. Mean Return: 2734.1791824039783. Mean Length: 500.0
#  Epoch: 5. Mean Return: 
Mean Length: 500.0
#  Epoch: 10. Mean Return: 3477.256625681207. Mean Length: 500.0
#  Epoch: 11. Mean Return: 1578.2400720520502. Mean Length: 500.0
#  Epoch: 12. Mean Return: 141.2404952281626. Mean Length: 500.0
#  Epoch: 13. Mean Return: 242.35420304564255. Mean Length: 500.0
#  Epoch: 14. Mean Return: 3379.865716118436. Mean Length: 500.0
#  Epoch: 15. Mean Return: 207.35243167982009. Mean Length: 500.0
#  Epoch: 16. Mean Return: 208.3007686303321. Mean Length: 500.0
#  Epoch: 17. Mean Return: 3972.947467446475. Mean Length: 500.0
#  Epoch: 18. Mean Return: 160.96667795236482. Mean Length: 500.0
#  Epoch: 19. Mean Return: 3542.681021904101. Mean Length: 500.0
#  Epoch: 20. Mean Return: 1309.1517269061237. Mean Length: 500.0
# Current batch mean is 57.08236813156519
# ----------
# Run #21. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: -23.00192307758182. Mean Length: 500.0
#  Epoch: 2. Mean Return: 1888.7765039611143. Mean Length: 500.0
#  Epoch: 3. Mean Return: 2340.2913110051263. Mean Length: 500.0
#  Epoch: 4. Mean Return: 1763.5220420521957. Mean Length: 500.0
#  Epoch: 5. Mean Return: 2555.2731588998486. Mean Length: 500.0
#  Epoch: 6. Mean Return: 80.9830485046606. Mean Length: 500.0
#  Epoch: 7. Mean Return: 3073.0443851268174. Mean Length: 500.0
#  Epoch: 8. Mean Return: 2326.4248743688795. Mean Length: 500.0
#  Epoch: 9. Mean Return: 1040.6534509371002. Mean Length: 500.0
#  Epoch: 10. Mean Return: 162.01196613619624. Mean Length: 500.0
#  Epoch: 11. Mean Return: 3069.774473622102. Mean Length: 500.0
#  Epoch: 12. Mean Return: 216.57874312986044. Mean Length: 500.0
#  Epoch: 13. Mean Return: 210.70963576021944. Mean Length: 500.0
#  Epoch: 14. Mean Return: 196.6111892314935. Mean Length: 500.0
#  Epoch: 15. Mean Return: 234.27286707278967. Mean Length: 500.0
#  Epoch: 16. Mean Return: 1116.9500921624897. Mean Length: 500.0
#  Epoch: 17. Mean Return: 1547.974874441952. Mean Length: 500.0
#  Epoch: 18. Mean Return: 18.60299169091462. Mean Length: 500.0
#  Epoch: 19. Mean Return: 91.20555975451444. Mean Length: 500.0
#  Epoch: 20. Mean Return: 964.4510153506208. Mean Length: 500.0
# Current batch mean is -23.00192307758182
# ----------
# Run #22. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 3379.12934591087. Mean Length: 500.0
#  Epoch: 2. Mean Return: 3622.78645300124. Mean Length: 500.0
#  Epoch: 3. Mean Return: 1258.0797007939955. Mean Length: 500.0
#  Epoch: 4. Mean Return: 183.4751530166431. Mean Length: 500.0
#  Epoch: 5. Mean Return: 3520.623824665775. Mean Length: 500.0
#  Epoch: 6. Mean Return: 3398.3416458074903. Mean Length: 500.0
#  Epoch: 7. Mean Return: 166.50851519472744. Mean Length: 500.0
#  Epoch: 8. Mean Return: 3488.967660420085. Mean Length: 500.0
#  Epoch: 9. Mean Return: 234.7135075757429. Mean Length: 500.0
#  Epoch: 10. Mean Return: 140.84675528150476. Mean Length: 500.0
#  Epoch: 11. Mean Return: 1323.0772679511495. Mean Length: 500.0
#  Epoch: 12. Mean Return: 26.60155072610044. Mean Length: 500.0
#  Epoch: 13. Mean Return: 215.129328217176. Mean Length: 500.0
#  Epoch: 14. Mean Return: 3278.982868995632. Mean Length: 500.0
#  Epoch: 15. Mean Return: 3135.451041429828. Mean Length: 500.0
#  Epoch: 16. Mean Return: 182.40451297433046. Mean Length: 500.0
#  Epoch: 17. Mean Return: 3820.336453591509. Mean Length: 500.0
#  Epoch: 18. Mean Return: 209.75136694389064. Mean Length: 500.0
#  Epoch: 19. Mean Return: 3825.807997140878. Mean Length: 500.0
#  Epoch: 20. Mean Return: 197.22292245882662. Mean Length: 500.0
# Current batch mean is 26.60155072610044
# ----------
# Run #23. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 2943.881591549962. Mean Length: 500.0
#  Epoch: 2. Mean Return: 2887.639693075291. Mean Length: 500.0
#  Epoch: 3. Mean Return: 207.98714114975658. Mean Length: 500.0
#  Epoch: 4. Mean Return: 159.46928518919844. Mean Length: 500.0
#  Epoch: 5. Mean Return: 202.00923224497038. Mean Length: 500.0
#  Epoch: 6. Mean Return: 1175.163021036853. Mean Length: 500.0
#  Epoch: 7. Mean Return: 174.4786139995364. Mean Length: 500.0
#  Epoch: 8. Mean Return: 339.11291520069636. Mean Length: 500.0
#  Epoch: 9. Mean Return: 129.8328146137555. Mean Length: 500.0
#  Epoch: 10. Mean Return: 9.432574124998185. Mean Length: 500.0
#  Epoch: 11. Mean Return: 3227.8410384288727. Mean Length: 500.0
#  Epoch: 12. Mean Return: 164.03113124492234. Mean Length: 500.0
#  Epoch: 13. Mean Return: 198.99804069742163. Mean Length: 500.0
#  Epoch: 14. Mean Return: 1096.8260147603721. Mean Length: 500.0
#  Epoch: 15. Mean Return: 663.0135181536173. Mean Length: 500.0
#  Epoch: 16. Mean Return: 171.86392288413145. Mean Length: 500.0
#  Epoch: 17. Mean Return: 179.44604338179002. Mean Length: 500.0
#  Epoch: 18. Mean Return: 172.10242583341338. Mean Length: 500.0
#  Epoch: 19. Mean Return: 148.53283462533977. Mean Length: 500.0
#  Epoch: 20. Mean Return: 115.39209500075711. Mean Length: 500.0
# Current batch mean is 9.432574124998185
# ----------
# Run #24. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 192.0327366884247. Mean Length: 500.0
#  Epoch: 2. Mean Return: 191.89814241193417. Mean Length: 500.0
#  Epoch: 3. Mean Return: 1632.1888523383125. Mean Length: 500.0
#  Epoch: 4. Mean Return: 176.64757856897134. Mean Length: 500.0
#  Epoch: 5. Mean Return: 350.71648581455463. Mean Length: 500.0
#  Epoch: 6. Mean Return: 191.12438091745662. Mean Length: 500.0
#  Epoch: 7. Mean Return: 1462.0795645288954. Mean Length: 500.0
#  Epoch: 8. Mean Return: 185.02998847730825. Mean Length: 500.0
#  Epoch: 9. Mean Return: 1419.4436101880601. Mean Length: 500.0
#  Epoch: 10. Mean Return: 97.1023305035003. Mean Length: 500.0
#  Epoch: 11. Mean Return: 227.0373423730352. Mean Length: 500.0
#  Epoch: 12. Mean Return: 211.89796726634663. Mean Length: 500.0
#  Epoch: 13. Mean Return: 1831.182476866611. Mean Length: 500.0
#  Epoch: 14. Mean Return: 1600.8666422583365. Mean Length: 500.0
#  Epoch: 15. Mean Return: 216.97393685807697. Mean Length: 500.0
#  Epoch: 16. Mean Return: 135.21156655240387. Mean Length: 500.0
#  Epoch: 17. Mean Return: 2292.7264122519073. Mean Length: 500.0
#  Epoch: 18. Mean Return: 3307.7332533799945. Mean Length: 500.0
#  Epoch: 19. Mean Return: 547.9437808648073. Mean Length: 500.0
#  Epoch: 20. Mean Return: 209.9983083269175. Mean Length: 500.0
# Current batch mean is 97.1023305035003
# ----------
# Run #25. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 404.8195561150945. Mean Length: 500.0
#  Epoch: 2. Mean Return: 523.9536210729568. Mean Length: 500.0
#  Epoch: 3. Mean Return: 3169.815782313001. Mean Length: 500.0
#  Epoch: 4. Mean Return: 164.21014508151254. Mean Length: 500.0
#  Epoch: 5. Mean Return: 614.0201153707727. Mean Length: 500.0
#  Epoch: 6. Mean Return: 584.8480765104239. Mean Length: 500.0
#  Epoch: 7. Mean Return: 3823.6409173306997. Mean Length: 500.0
#  Epoch: 8. Mean Return: 3013.6385572691524. Mean Length: 500.0
#  Epoch: 9. Mean Return: 180.6143587915959. Mean Length: 500.0
#  Epoch: 10. Mean Return: 181.6708739777539. Mean Length: 500.0
#  Epoch: 11. Mean Return: 3329.4743663361924. Mean Length: 500.0
#  Epoch: 12. Mean Return: 1403.1803770994322. Mean Length: 500.0
#  Epoch: 13. Mean Return: 1255.4632613436518. Mean Length: 500.0
#  Epoch: 14. Mean Return: 170.37933759783544. Mean Length: 500.0
#  Epoch: 15. Mean Return: 1920.220758949255. Mean Length: 500.0
#  Epoch: 16. Mean Return: 191.01352483402675. Mean Length: 500.0
#  Epoch: 17. Mean Return: 120.06177396142057. Mean Length: 500.0
#  Epoch: 18. Mean Return: 1280.5180988079385. Mean Length: 500.0
#  Epoch: 19. Mean Return: 212.08424210284636. Mean Length: 500.0
#  Epoch: 20. Mean Return: 192.90895011599008. Mean Length: 500.0
# Current batch mean is 120.06177396142057
# ----------
# Run #26. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 99.42544758886343. Mean Length: 500.0
#  Epoch: 2. Mean Return: 3489.256783404374. Mean Length: 500.0
#  Epoch: 3. Mean Return: 203.7695994257816. Mean Length: 500.0
#  Epoch: 4. Mean Return: 151.32872024586658. Mean Length: 500.0
#  Epoch: 5. Mean Return: 3462.561611425405. Mean Length: 500.0
#  Epoch: 6. Mean Return: 181.39069072329752. Mean Length: 500.0
#  Epoch: 7. Mean Return: 191.56024383247447. Mean Length: 500.0
#  Epoch: 8. Mean Return: 121.78460828800448. Mean Length: 500.0
#  Epoch: 9. Mean Return: 84.32080186561292. Mean Length: 500.0
#  Epoch: 10. Mean Return: 194.6596853248828. Mean Length: 500.0
#  Epoch: 11. Mean Return: 207.87341053557773. Mean Length: 500.0
#  Epoch: 12. Mean Return: 188.26987323059836. Mean Length: 500.0
#  Epoch: 13. Mean Return: 197.3052638958509. Mean Length: 500.0
#  Epoch: 14. Mean Return: 175.40701939444142. Mean Length: 500.0
#  Epoch: 15. Mean Return: -40.83835682212931. Mean Length: 500.0
#  Epoch: 16. Mean Return: 1470.1432308103424. Mean Length: 500.0
#  Epoch: 17. Mean Return: 574.6243089859405. Mean Length: 500.0
#  Epoch: 18. Mean Return: 196.2809258873569. Mean Length: 500.0
#  Epoch: 19. Mean Return: 97.34698501808656. Mean Length: 500.0
#  Epoch: 20. Mean Return: 70.98556554785428. Mean Length: 500.0
# Current batch mean is -40.83835682212931
# ----------
# Run #27. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 1301.5813773722912. Mean Length: 500.0
#  Epoch: 2. Mean Return: 207.77046998441975. Mean Length: 500.0
#  Epoch: 3. Mean Return: 945.6334205766248. Mean Length: 500.0
#  Epoch: 4. Mean Return: 3203.7927418318277. Mean Length: 500.0
#  Epoch: 5. Mean Return: 3524.3688689092037. Mean Length: 500.0
#  Epoch: 6. Mean Return: 185.04924342815406. Mean Length: 500.0
#  Epoch: 7. Mean Return: 95.41672015453965. Mean Length: 500.0
#  Epoch: 8. Mean Return: 3227.3909963141086. Mean Length: 500.0
#  Epoch: 9. Mean Return: 1797.6705214211856. Mean Length: 500.0
#  Epoch: 10. Mean Return: 196.51361076707772. Mean Length: 500.0
#  Epoch: 11. Mean Return: 2990.358397500231. Mean Length: 500.0
#  Epoch: 12. Mean Return: 82.769754380046. Mean Length: 500.0
#  Epoch: 13. Mean Return: 890.1952745105659. Mean Length: 500.0
#  Epoch: 14. Mean Return: 67.35623843339617. Mean Length: 500.0
#  Epoch: 15. Mean Return: 1297.6187611030753. Mean Length: 500.0
#  Epoch: 16. Mean Return: 164.473190555289. Mean Length: 500.0
#  Epoch: 17. Mean Return: 
Mean Length: 500.0
#  Epoch: 10. Mean Return: 3169.5620236698114. Mean Length: 500.0
#  Epoch: 11. Mean Return: 190.8507607266064. Mean Length: 500.0
#  Epoch: 12. Mean Return: 261.68283305695945. Mean Length: 500.0
#  Epoch: 13. Mean Return: 3949.9799586774466. Mean Length: 500.0
#  Epoch: 14. Mean Return: 4096.584281952925. Mean Length: 500.0
#  Epoch: 15. Mean Return: 3703.2299254191394. Mean Length: 500.0
#  Epoch: 16. Mean Return: 2621.47396643589. Mean Length: 500.0
#  Epoch: 17. Mean Return: 4155.7502241738985. Mean Length: 500.0
#  Epoch: 18. Mean Return: 207.78095242704688. Mean Length: 500.0
#  Epoch: 19. Mean Return: 176.12040891947558. Mean Length: 500.0
#  Epoch: 20. Mean Return: 251.2484982959131. Mean Length: 500.0
# Current batch mean is 176.12040891947558
# ----------
# Run #31. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 166.99288820251195. Mean Length: 500.0
#  Epoch: 2. Mean Return: 131.69837611848016. Mean Length: 500.0
#  Epoch: 3. Mean Return: 3871.4817906590347. Mean Length: 500.0
#  Epoch: 4. Mean Return: 4482.021735094163. Mean Length: 500.0
#  Epoch: 5. Mean Return: 149.73892111882452. Mean Length: 500.0
#  Epoch: 6. Mean Return: 4510.080521976595. Mean Length: 500.0
#  Epoch: 7. Mean Return: 4390.921326399942. Mean Length: 500.0
#  Epoch: 8. Mean Return: 163.42437001242956. Mean Length: 500.0
#  Epoch: 9. Mean Return: 158.79168800279885. Mean Length: 500.0
#  Epoch: 10. Mean Return: 768.3367558317951. Mean Length: 500.0
#  Epoch: 11. Mean Return: 4252.164643638256. Mean Length: 500.0
#  Epoch: 12. Mean Return: 2808.8097882980696. Mean Length: 500.0
#  Epoch: 13. Mean Return: 4132.674766077147. Mean Length: 500.0
#  Epoch: 14. Mean Return: 3637.75406121578. Mean Length: 500.0
#  Epoch: 15. Mean Return: 214.11982027649148. Mean Length: 500.0
#  Epoch: 16. Mean Return: 2218.21421198067. Mean Length: 500.0
#  Epoch: 17. Mean Return: 245.4755576938355. Mean Length: 500.0
#  Epoch: 18. Mean Return: 3493.9745096600773. Mean Length: 500.0
#  Epoch: 19. Mean Return: 1543.8627684340258. Mean Length: 500.0
#  Epoch: 20. Mean Return: 431.59490436598827. Mean Length: 500.0
# Current batch mean is 131.69837611848016
# ----------
# Run #32. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 4227.99077037483. Mean Length: 500.0
#  Epoch: 2. Mean Return: 4700.8529576811725. Mean Length: 500.0
#  Epoch: 3. Mean Return: 3371.009269998658. Mean Length: 500.0
#  Epoch: 4. Mean Return: 33.73536607176368. Mean Length: 500.0
#  Epoch: 5. Mean Return: 288.0119557460575. Mean Length: 500.0
#  Epoch: 6. Mean Return: 2759.969596559317. Mean Length: 500.0
#  Epoch: 7. Mean Return: 180.00620397374897. Mean Length: 500.0
#  Epoch: 8. Mean Return: 2683.4301141690266. Mean Length: 500.0
#  Epoch: 9. Mean Return: 4282.250074663016. Mean Length: 500.0
#  Epoch: 10. Mean Return: 2981.0755132605527. Mean Length: 500.0
#  Epoch: 11. Mean Return: 3685.169797684469. Mean Length: 500.0
#  Epoch: 12. Mean Return: 3026.1656740958024. Mean Length: 500.0
#  Epoch: 13. Mean Return: 4158.008765749807. Mean Length: 500.0
#  Epoch: 14. Mean Return: 161.51859367015084. Mean Length: 500.0
#  Epoch: 15. Mean Return: 183.3139309500465. Mean Length: 500.0
#  Epoch: 16. Mean Return: 1999.4727594723227. Mean Length: 500.0
#  Epoch: 17. Mean Return: 107.55544812210081. Mean Length: 500.0
#  Epoch: 18. Mean Return: 3464.3652548176324. Mean Length: 500.0
#  Epoch: 19. Mean Return: 4203.370146251851. Mean Length: 500.0
#  Epoch: 20. Mean Return: 188.567498035404. Mean Length: 500.0
# Current batch mean is 33.73536607176368
# ----------
# Run #33. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 184.3078543549436. Mean Length: 500.0
#  Epoch: 2. Mean Return: 4123.286800471226. Mean Length: 500.0
#  Epoch: 3. Mean Return: 3985.269163057341. Mean Length: 500.0
#  Epoch: 4. Mean Return: 880.5598994004163. Mean Length: 500.0
#  Epoch: 5. Mean Return: 3105.587486704888. Mean Length: 500.0
#  Epoch: 6. Mean Return: 
Mean Length: 500.0
#  Epoch: 14. Mean Return: 3027.785074891708. Mean Length: 500.0
#  Epoch: 15. Mean Return: 202.86369947822035. Mean Length: 500.0
#  Epoch: 16. Mean Return: 254.4507989191572. Mean Length: 500.0
#  Epoch: 17. Mean Return: 182.45799002184214. Mean Length: 500.0
#  Epoch: 18. Mean Return: 142.70348649514747. Mean Length: 500.0
#  Epoch: 19. Mean Return: 4391.461430462837. Mean Length: 500.0
#  Epoch: 20. Mean Return: 216.39854796801737. Mean Length: 500.0
# Current batch mean is 21.615951606185185
# ----------
# Run #90. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 227.12039159384165. Mean Length: 500.0
#  Epoch: 2. Mean Return: 1231.792147652837. Mean Length: 500.0
#  Epoch: 3. Mean Return: 181.4790010534623. Mean Length: 500.0
#  Epoch: 4. Mean Return: 155.88369691510545. Mean Length: 500.0
#  Epoch: 5. Mean Return: 170.06142016452958. Mean Length: 500.0
#  Epoch: 6. Mean Return: 142.13905568081856. Mean Length: 500.0
#  Epoch: 7. Mean Return: 3205.1892493902888. Mean Length: 500.0
#  Epoch: 8. Mean Return: 4327.049670844557. Mean Length: 500.0
#  Epoch: 9. Mean Return: 3713.0619322499747. Mean Length: 500.0
#  Epoch: 10. Mean Return: 3550.830434688516. Mean Length: 500.0
#  Epoch: 11. Mean Return: 59.098235172975315. Mean Length: 500.0
#  Epoch: 12. Mean Return: 160.23406840665913. Mean Length: 500.0
#  Epoch: 13. Mean Return: 3496.2780126567445. Mean Length: 500.0
#  Epoch: 14. Mean Return: 3971.295138292071. Mean Length: 500.0
#  Epoch: 15. Mean Return: -148.56449595492757. Mean Length: 500.0
#  Epoch: 16. Mean Return: 388.4702011306462. Mean Length: 500.0
#  Epoch: 17. Mean Return: 2948.936620059398. Mean Length: 500.0
#  Epoch: 18. Mean Return: 392.39596161268696. Mean Length: 500.0
#  Epoch: 19. Mean Return: 4104.1811179537945. Mean Length: 500.0
#  Epoch: 20. Mean Return: 368.53176733660405. Mean Length: 500.0
# Current batch mean is -148.56449595492757
# ----------
# Run #91. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 337.64862534887425. Mean Length: 500.0
#  Epoch: 2. Mean Return: 4587.656088559041. Mean Length: 500.0
#  Epoch: 3. Mean Return: 505.3372711444848. Mean Length: 500.0
#  Epoch: 4. Mean Return: 3173.9978104464612. Mean Length: 500.0
#  Epoch: 5. Mean Return: 4666.875589071222. Mean Length: 500.0
#  Epoch: 6. Mean Return: 212.47345847024704. Mean Length: 500.0
#  Epoch: 7. Mean Return: 3001.076098746907. Mean Length: 500.0
#  Epoch: 8. Mean Return: 219.5639853762083. Mean Length: 500.0
#  Epoch: 9. Mean Return: 786.3315326009098. Mean Length: 500.0
#  Epoch: 10. Mean Return: 3936.7101969897326. Mean Length: 500.0
#  Epoch: 11. Mean Return: -60.18889912108909. Mean Length: 500.0
#  Epoch: 12. Mean Return: 4098.522935982477. Mean Length: 500.0
#  Epoch: 13. Mean Return: 3582.5337502389575. Mean Length: 500.0
#  Epoch: 14. Mean Return: 3455.258594744825. Mean Length: 500.0
#  Epoch: 15. Mean Return: 224.71998974047725. Mean Length: 500.0
#  Epoch: 16. Mean Return: 2609.292994564419. Mean Length: 500.0
#  Epoch: 17. Mean Return: 1258.9444531820461. Mean Length: 500.0
#  Epoch: 18. Mean Return: 3772.8819324701126. Mean Length: 500.0
#  Epoch: 19. Mean Return: 2098.890305979935. Mean Length: 500.0
#  Epoch: 20. Mean Return: 181.77116997826485. Mean Length: 500.0
# Current batch mean is -60.18889912108909
# ----------
# Run #92. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 3741.7272489571956. Mean Length: 500.0
#  Epoch: 2. Mean Return: 3548.1492546010695. Mean Length: 500.0
#  Epoch: 3. Mean Return: 23.004300727008058. Mean Length: 500.0
#  Epoch: 4. Mean Return: 4688.010957121716. Mean Length: 500.0
#  Epoch: 5. Mean Return: 188.44861056435195. Mean Length: 500.0
#  Epoch: 6. Mean Return: 3412.9780145395803. Mean Length: 500.0
#  Epoch: 7. Mean Return: -62.11710630399146. Mean Length: 500.0
#  Epoch: 8. Mean Return: 3580.337509132582. Mean Length: 500.0
#  Epoch: 9. Mean Return: 4120.877425449635. Mean Length: 500.0
#  Epoch: 10. Mean Return: 3253.6185370990033. Mean Length: 500.0
#  Epoch: 11. Mean Return: 4718.105851847908. Mean Length: 500.0
#  Epoch: 12. Mean Return: 106.91249186145438. Mean Length: 500.0
#  Epoch: 13. Mean Return: 3342.7820938786795. Mean Length: 500.0
#  Epoch: 14. Mean Return: 4185.963479208035. Mean Length: 500.0
#  Epoch: 15. Mean Return: 3877.670257968065. Mean Length: 500.0
#  Epoch: 16. Mean Return: 137.38429107153732. Mean Length: 500.0
#  Epoch: 17. Mean Return: 4604.114965877692. Mean Length: 500.0
#  Epoch: 18. Mean Return: 
The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 1029.8774428542029. Mean Length: 500.0
#  Epoch: 2. Mean Return: 249.85086938368468. Mean Length: 500.0
#  Epoch: 3. Mean Return: 1870.618552682956. Mean Length: 500.0
#  Epoch: 4. Mean Return: 3296.05008800818. Mean Length: 500.0
#  Epoch: 5. Mean Return: 112.11893892639503. Mean Length: 500.0
#  Epoch: 6. Mean Return: 2067.633339908992. Mean Length: 500.0
#  Epoch: 7. Mean Return: 3758.8018805125366. Mean Length: 500.0
#  Epoch: 8. Mean Return: 815.1371566243998. Mean Length: 500.0
#  Epoch: 9. Mean Return: 1106.7338078633645. Mean Length: 500.0
#  Epoch: 10. Mean Return: 1176.3922399729443. Mean Length: 500.0
#  Epoch: 11. Mean Return: 3294.677457553714. Mean Length: 500.0
#  Epoch: 12. Mean Return: 248.81996461334145. Mean Length: 500.0
#  Epoch: 13. Mean Return: 79.53924039654895. Mean Length: 500.0
#  Epoch: 14. Mean Return: 3466.5019889079595. Mean Length: 500.0
#  Epoch: 15. Mean Return: 1466.7088454360269. Mean Length: 500.0
#  Epoch: 16. Mean Return: 3315.5171419264816. Mean Length: 500.0
#  Epoch: 17. Mean Return: 139.75310895394276. Mean Length: 500.0
#  Epoch: 18. Mean Return: 183.02619728348162. Mean Length: 500.0
#  Epoch: 19. Mean Return: 685.9277724239101. Mean Length: 500.0
#  Epoch: 20. Mean Return: 4056.0823558869274. Mean Length: 500.0
# Current batch mean is 79.53924039654895
# ----------
# Run #99. The "+9" threshold is 0.1
# starting training with 20 epochs
#  Epoch: 1. Mean Return: 168.30616528302795. Mean Length: 500.0
#  Epoch: 2. Mean Return: 4242.24780526796. Mean Length: 500.0
#  Epoch: 3. Mean Return: 124.34358166056292. Mean Length: 500.0
#  Epoch: 4. Mean Return: 4488.234555018428. Mean Length: 500.0
#  Epoch: 5. Mean Return: 979.4210520900721. Mean Length: 500.0
#  Epoch: 6. Mean Return: 154.72569903740015. Mean Length: 500.0
#  Epoch: 7. Mean Return: 175.5555007459681. Mean Length: 500.0
#  Epoch: 8. Mean Return: 119.11412718910604. Mean Length: 500.0
#  Epoch: 9. Mean Return: 158.6775918896326. Mean Length: 500.0
#  Epoch: 10. Mean Return: 1162.513827664556. Mean Length: 500.0
#  Epoch: 11. Mean Return: 4680.116106820311. Mean Length: 500.0
#  Epoch: 12. Mean Return: 450.5698611688081. Mean Length: 500.0
#  Epoch: 13. Mean Return: 94.54517770871475. Mean Length: 500.0
#  Epoch: 14. Mean Return: 3595.8971964928396. Mean Length: 500.0
#  Epoch: 15. Mean Return: 4532.752050229797. Mean Length: 500.0
#  Epoch: 16. Mean Return: 3568.017065848232. Mean Length: 500.0
#  Epoch: 17. Mean Return: 4374.853525002332. Mean Length: 500.0
#  Epoch: 18. Mean Return: 505.98630102866764. Mean Length: 500.0
#  Epoch: 19. Mean Return: 4100.105443240397. Mean Length: 500.0
#  Epoch: 20. Mean Return: 3277.4341949042505. Mean Length: 500.0
# Current batch mean is 94.54517770871475
# ----------

# %%
observation = env.reset()
episode_return = 0
# Iterate over the steps of each epoch
for t in range(steps_per_epoch*2):
    if render:
        env.render()

    # Get the logits, action, and take one step in the environment
    observation = observation.reshape(1, -1)
    logits, action = sample_action(observation)
    #print(type(action[0].numpy()))
    observation_new, reward, done, info = env.step(action[0].numpy())
    episode_return += reward

    # Update the observation
    observation = observation_new
print(episode_return)
# Out:
# 466.51592844943906

# %%
x = np.array(info['x'])
t = np.array(info['t'])
roll, pitch, yaw = quat2rpy_deg(x[:,0], x[:,1], x[:,2], x[:,3])
size = roll.shape[0]//3
print(np.mean(roll[-size:]))
print(np.mean(pitch[-size:]))
print(np.mean(yaw[-size:]))
print(np.std(roll[-size:]))
print(np.std(pitch[-size:]))
print(np.std(yaw[-size:]))

plot_euler_angles(t, roll, pitch, yaw, 'angles2.pdf')
# Out:
# 0.07942169665552358
# -0.19945675484643768
# 1.0682963399762604
# 0.7690845118085
# 0.4408515561729276
# 0.7782379416433071

# %%
start = np.array([np.cos(0.001),0,0,np.sin(0.001),0,0,0,0,0,0])

# %%
x = np.array(info['x'])
t = np.array(info['t'])
roll, pitch, yaw = quat2rpy(x[:,0], x[:,1], x[:,2], x[:,3])

plot_euler_angles_radial(t, roll, pitch, yaw, 'angles2.pdf')

# %%
roll, pitch, yaw = quat2rpy_deg(x[:,0], x[:,1], x[:,2], x[:,3])
   
fig1 = plt.figure(figsize=(16,8))
ax1 = fig1.add_subplot(2,2,1)

ax1.set_title("Euler Angles")
ax1.plot(t, roll, label = 'roll', color = 'red')
ax1.plot(t, pitch, label = 'pitch', color = 'green')
ax1.plot(t, yaw, label = 'yaw', color = 'blue')
ax1.set_ylabel(r'angles, [deg]')
ax1.set_xlabel(r't, [s]')
ax1.grid(True)
ax1.legend()

ax2 = fig1.add_subplot(2,2,2)

ax2.set_title("Angular Velocity")
ax2.plot(t, x[1:,4], label = '$\omega_x$', color = 'red')
ax2.plot(t, x[1:,5], label = '$\omega_y$', color = 'green')
ax2.plot(t, x[1:,6], label = '$\omega_z$', color = 'blue')
ax2.set_ylabel(r'angular velocity, [rad/s]')
ax2.set_xlabel(r't, [s]')
ax2.grid(True)
ax2.legend()

ax2 = fig1.add_subplot(2,2,3)

ax2.set_title("RW angular momentum")
ax2.plot(t, x[1:,7], label = '$h_x$', color = 'red')
ax2.plot(t, x[1:,8], label = '$h_y$', color = 'green')
ax2.plot(t, x[1:,9], label = '$h_z$', color = 'blue')
ax2.set_ylabel(r'h, [Nms]')
ax2.set_xlabel(r't, [s]')
ax2.grid(True)
ax2.legend()

plt.tight_layout()

# %% [markdown]
# ## Saving the weights

# %%
actor_config = actor.get_config()
actor_weights = actor.get_weights()
critic_config = critic.get_config()
critic_weights = critic.get_weights()
import pickle
name = f'configs_weights{iterations} {reward_thresh}.pickle'
with open(name, 'wb') as f:
  pickle.dump((actor_config, actor_weights, critic_config, critic_weights), f)
from google.colab import files
files.download(name)

# %% [markdown]
# ## Importing the weights

# %%
import pickle
# iterations = 1500
# reward_thresh = 0.0043
name = f'configs_weights_gravity_usual.pickle'
with open(name, 'rb') as f:
  something = pickle.load(f)

actor_config, actor_weights ,critic_config, critic_weights = something
actor = keras.Model.from_config(actor_config)
actor.set_weights(actor_weights)
critic = keras.Model.from_config(critic_config)
critic.set_weights(critic_weights)

# %%
sum(pitch > -1), pitch.shape[0]
# Out:
# (48799, 50001)
